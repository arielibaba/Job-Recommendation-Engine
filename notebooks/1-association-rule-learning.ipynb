# %% [markdown]
# # Association Rule Learning
#
# ### In this notebook, we perform association rule learning to extract statistiscally relevant associations between the professions.

# %% [markdown]
# ### Import libraries

# %%
import os, sys, time
import pandas as pd, numpy as np
import random
import pickle
from natsort import natsorted
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules

# %% [markdown]
# ### Global variables

# %%
DATA = os.path.join('..', 'data')
RESULTS = os.path.join('..', 'results')

# %% [markdown]
# ## Load the data

# %%
with open(os.path.join(DATA, 'dataset.pkl'), 'rb') as d:
    pkl_data = pickle.load(d)

# %%
type(pkl_data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(f'Size of the data: {pkl_data.shape}\n\n')
pkl_data.head(3)
# Out:
# Size of the data: (325989, 6)
#                               worker_id                              order_id  \
# 0  0003e59c-a459-4842-b0ec-67a996c9f2fc  88f6eb57-c59a-4808-a05f-23350cb17a08
# 1  00afbab3-b57c-4417-9bc1-4ebeb05496d4  88f6eb57-c59a-4808-a05f-23350cb17a08
# 2  06ac473d-3114-4e9a-9e58-8f187e3959d1  88f6eb57-c59a-4808-a05f-23350cb17a08
#
#                             list_profession_2  \
# 0                                     [Vente]
# 1  [Entretien, Manutention, Service en salle]
# 2       [Magasinage, Magasinage, Manutention]
#
#                                    list_profession_3  \
# 0                                          [Vendeur]
# 1  [Agent de nettoyage, Manutentionnaire, Serveur...
# 2  [Agent de conditionnement, Manutentionnaire, P...
#
#                              order_list_profession_3  \
# 0  [Préparateur de commandes, Agent de conditionn...
# 1  [Préparateur de commandes, Agent de conditionn...
# 2  [Préparateur de commandes, Agent de conditionn...
#
#                  order_list_profession_2
# 0  [Magasinage, Magasinage, Manutention]
# 1  [Magasinage, Magasinage, Manutention]
# 2  [Magasinage, Magasinage, Manutention]

# %% [markdown]
# # Association Learning
#
# We use statistical learning to extract the potential valid associations between the different professions.

# %% [markdown]
# # Step 1: Creating a list with the required data

# %% [markdown]
# ### We will use only the column list_profession_3 that designates the jobs as such

# %%
dataset = pkl_data.list_profession_3.tolist() + pkl_data.order_list_profession_3.tolist()
dataset = [natsorted(list(set(el))) for el in dataset]
dataset = [[w for w in el if w and w != 'nan' and len(w.split())>0] for el in dataset]
random.shuffle(dataset)

# %%
dataset[:5]
# Out:
# [['Préparateur de commandes', 'Serveur et barman'],
#  ['Commis de cuisine', 'Plongeur', 'Préparateur de commandes', 'Vendeur'],
#  ['Vendeur'],
#  ['Serveur et barman'],
#  ['Préparateur de commandes']]

# %% [markdown]
# # Step 2: Convert list to dataframe with boolean values

# %%
te = TransactionEncoder()
te_array = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_array, columns=te.columns_)

# %%
print(f'Data size: {df.shape}\n\n')
df.head()
# Out:
# Data size: (651978, 183)
#    Accompagnant éducatif et social  Accompagnateur  Acheteur  \
# 0                            False           False     False
# 1                            False           False     False
# 2                            False           False     False
# 3                            False           False     False
# 4                            False           False     False
#
#    Administration des ventes  Affrètement  Agent d'entretien  \
# 0                      False        False              False
# 1                      False        False              False
# 2                      False        False              False
# 3                      False        False              False
# 4                      False        False              False
#
#    Agent d'exploitation  Agent de conditionnement  Agent de distribution  \
# 0                 False                     False                  False
# 1                 False                     False                  False
# 2                 False                     False                  False
# 3                 False                     False                  False
# 4                 False                     False                  False
#
#    Agent de nettoyage  ...  Tourneur / Fraiseur  Traducteur  \
# 0               False  ...                False       False
# 1               False  ...                False       False
# 2               False  ...                False       False
# 3               False  ...                False       False
# 4               False  ...                False       False
#
#    Transaction immobilière  Transport de personnes  Trésorerie  Tuyauteur  \
# 0                    False                   False       False      False
# 1                    False                   False       False      False
# 2                    False                   False       False      False
# 3                    False                   False       False      False
# 4                    False                   False       False      False
#
#    Téléprospecteur  Veilleur de nuit  Vendeur  Éducateur de jeunes enfants
# 0            False             False    False                        False
# 1            False             False     True                        False
# 2            False             False     True                        False
# 3            False             False    False                        False
# 4            False             False    False                        False
#
# [5 rows x 183 columns]

# %% [markdown]
# # Step 3: Find frequently occurring itemsets using F-P Growth

# %% [markdown]
# ### We can define a threshold for the number of occurrences of the itemset we want to retain.

# %%
min_occurences = 10
min_support = round(min_occurences / len(df), 5)
# min_support = 0.0001 * len(df)
min_support
# Out:
# 2e-05

# %%
# %%time
frequent_itemsets_fp = fpgrowth(df, min_support=min_support, use_colnames=True)
# Out:
# CPU times: user 3.21 s, sys: 24 ms, total: 3.23 s
# Wall time: 3.23 s

# %%
frequent_itemsets_fp
# Out:
#         support                                           itemsets
# 0      0.375448                         (Préparateur de commandes)
# 1      0.022867                                (Serveur et barman)
# 2      0.166814                                          (Vendeur)
# 3      0.013527                                (Commis de cuisine)
# 4      0.005730                                         (Plongeur)
# ...         ...                                                ...
# 70597  0.000069  (Electrotechnicien, Electronicien, Technicien ...
# 70598  0.000069  (Mécanicien, Electromécanicien, Electronicien,...
# 70599  0.000023  (Préparateur de commandes, Electronicien, Manu...
# 70600  0.000021    (Electrotechnicien, Electronicien, Electricien)
# 70601  0.000023         (Infirmier de santé au travail, Infirmier)
#
# [70602 rows x 2 columns]

# %% [markdown]
# # Step 4: Mine the Association Rules
#
# ### In this final step we will perform the association rule mining in Python for the frequent itemsets which we calculated in Step 3.

# %%
# %%time
rules_fp = association_rules(frequent_itemsets_fp, metric="lift", min_threshold=1) # lift > 1: associated professions are not independant
# we could consider another metric to set the treshold, e.g. the confidence: 
# rules_fp = association_rules(frequent_itemsets_fp, metric="confidence", min_threshold=0.8)
# Out:
# CPU times: user 33.2 s, sys: 1.99 s, total: 35.2 s
# Wall time: 35.2 s

# %%
rules_fp.sort_values(['confidence', 'lift'], ascending=False)
# Out:
#                                                antecedents  \
# 85375    (Chauffeur VL, Restauration diverse, Commis de...
# 85394        (Agent de conditionnement, Cariste, Plongeur)
# 85757    (Chauffeur VL, Manutentionnaire, Commis de cui...
# 85768        (Agent de conditionnement, Cariste, Plongeur)
# 85883    (Préparateur de commandes, Chauffeur VL, Commi...
# ...                                                    ...
# 3634233                         (Préparateur de commandes)
# 4425609                         (Préparateur de commandes)
# 2810572                         (Préparateur de commandes)
# 2810784                         (Préparateur de commandes)
# 4043882                         (Préparateur de commandes)
#
#                                                consequents  \
# 85375        (Agent de conditionnement, Cariste, Plongeur)
# 85394    (Chauffeur VL, Restauration diverse, Commis de...
# 85757        (Agent de conditionnement, Cariste, Plongeur)
# 85768    (Chauffeur VL, Manutentionnaire, Commis de cui...
# 85883        (Agent de conditionnement, Cariste, Plongeur)
# ...                                                    ...
# 3634233              (Accompagnateur, Vendeur, Déménageur)
# 4425609  (Animatrice d'éveil, Agent de service hospital...
# 2810572  (Secrétaire médical / médicale, Hôte d'accueil...
# 2810784  (Hôte d'accueil, Opérateur de saisie, Assistan...
# 4043882  (Auxiliaire de vie sociale, Hôte d'accueil, As...
#
#          antecedent support  consequent support   support  confidence  \
# 85375              0.000021            0.000021  0.000021    1.000000
# 85394              0.000021            0.000021  0.000021    1.000000
# 85757              0.000021            0.000021  0.000021    1.000000
# 85768              0.000021            0.000021  0.000021    1.000000
# 85883              0.000021            0.000021  0.000021    1.000000
# ...                     ...                 ...       ...         ...
# 3634233            0.375448            0.000055  0.000021    0.000057
# 4425609            0.375448            0.000055  0.000021    0.000057
# 2810572            0.375448            0.000057  0.000021    0.000057
# 2810784            0.375448            0.000057  0.000021    0.000057
# 4043882            0.375448            0.000057  0.000021    0.000057
#
#                  lift      leverage  conviction
# 85375    46569.857143  2.147266e-05         inf
# 85394    46569.857143  2.147266e-05         inf
# 85757    46569.857143  2.147266e-05         inf
# 85768    46569.857143  2.147266e-05         inf
# 85883    46569.857143  2.147266e-05         inf
# ...               ...           ...         ...
# 3634233      1.035799  7.421461e-07    1.000002
# 4425609      1.035799  7.421461e-07    1.000002
# 2810572      1.007804  1.662858e-07    1.000000
# 2810784      1.007804  1.662858e-07    1.000000
# 4043882      1.007804  1.662858e-07    1.000000
#
# [6010854 rows x 9 columns]

# %%
rules_fp_reduced = rules_fp.copy()
cols = rules_fp_reduced.columns
rules_fp_reduced['antecedents_length'] = rules_fp_reduced['antecedents'].map(lambda x: len(x))
rules_fp_reduced['consequents_length'] = rules_fp_reduced['consequents'].map(lambda x: len(x))
rules_fp_reduced = rules_fp_reduced[rules_fp_reduced['antecedents_length'] == 1]

for c in ['antecedents', 'consequents']:
    rules_fp_reduced[c] = rules_fp_reduced[c].apply(list)
    
rules_fp_reduced['antecedents'] = rules_fp_reduced['antecedents'].apply(lambda x: x[0])
rules_fp_reduced = rules_fp_reduced[cols]
rules_fp_reduced = rules_fp_reduced.sort_values(['confidence', 'lift'], ascending=False).reset_index(drop=True)

# %% [markdown]
# ### We can add a confidence threshold to filter the rules we want to retain

# %%
min_conf_threshold = 0.5
rules_fp_reduced = rules_fp_reduced[rules_fp_reduced['confidence'] > min_conf_threshold]
rules_fp_reduced = rules_fp_reduced.sort_values(['confidence', 'lift'], ascending=False).reset_index(drop=True)
rules_fp_reduced = rules_fp_reduced.round(decimals={c: 2 for c in list(rules_fp_reduced.columns[2:])})
rules_fp_reduced
# Out:
#                        antecedents  \
# 0    Infirmier de santé au travail
# 1                   Réceptionnaire
# 2                       Déménageur
# 3         Agent de conditionnement
# 4                       Déménageur
# ..                             ...
# 544                    Examinateur
# 545          Agent de distribution
# 546                 Réceptionnaire
# 547       Chauffeur SPL messagerie
# 548                      Plaquiste
#
#                                       consequents  antecedent support  \
# 0                                     [Infirmier]                0.00
# 1                      [Préparateur de commandes]                0.00
# 2                      [Préparateur de commandes]                0.01
# 3                      [Préparateur de commandes]                0.11
# 4                              [Manutentionnaire]                0.01
# ..                                            ...                 ...
# 544           [Assistant polyvalent / Secrétaire]                0.00
# 545                    [Préparateur de commandes]                0.00
# 546  [Préparateur de commandes, Manutentionnaire]                0.00
# 547      [Chauffeur SPL national / international]                0.00
# 548                    [Préparateur de commandes]                0.00
#
#      consequent support  support  confidence    lift  leverage  conviction
# 0                  0.00     0.00        0.88  845.99      0.00        8.49
# 1                  0.38     0.00        0.82    2.17      0.00        3.38
# 2                  0.38     0.00        0.79    2.10      0.00        2.93
# 3                  0.38     0.09        0.78    2.07      0.04        2.81
# 4                  0.19     0.00        0.75    3.87      0.00        3.19
# ..                  ...      ...         ...     ...       ...         ...
# 544                0.05     0.00        0.51   10.63      0.00        1.94
# 545                0.38     0.00        0.51    1.35      0.00        1.27
# 546                0.14     0.00        0.50    3.69      0.00        1.74
# 547                0.00     0.00        0.50  625.91      0.00        2.01
# 548                0.38     0.00        0.50    1.33      0.00        1.25
#
# [549 rows x 9 columns]

# %% [markdown]
# ### We reduce the rules by joining the list of consequents with the same antecedents
# ### Without taking into account the confidence, lift, leverage and conviction

# %%
antecedents = natsorted(list(set(rules_fp_reduced.antecedents)))
clusters = {}

for antecedent in antecedents:
    consequents_list = list(rules_fp_reduced[rules_fp_reduced['antecedents'] == antecedent]['consequents'])
    clusters[antecedent] = natsorted(list(set([consequent for consequents in consequents_list for consequent in consequents])))
    
clusters_df = pd.DataFrame.from_dict(clusters, orient='index')
professions = []

for idx in range(len(clusters_df)):
    professions.append(clusters_df.iloc[idx, :].tolist())
professions = [[prof for prof in profs if prof] for profs in professions]

clusters_df['consequents'] = professions
clusters_df = clusters_df['consequents']
clusters_df = clusters_df.reset_index()
clusters_df.columns = ['antecedents', 'consequents']
clusters_df['size'] = clusters_df['consequents'].apply(lambda x: len(x))
clusters_df = clusters_df.sort_values('size', ascending=False).reset_index(drop=True)
clusters_df = clusters_df.reset_index()
clusters_df.columns.values[0] = 'cluster'
clusters_df
# Out:
#     cluster                            antecedents  \
# 0         0                             Déménageur
# 1         1                         Réceptionnaire
# 2         2                          Electronicien
# 3         3                              Manoeuvre
# 4         4                      Chargé d'affaires
# 5         5               Agent de conditionnement
# 6         6                            Examinateur
# 7         7                  Agent de distribution
# 8         8                              Plaquiste
# 9         9                     Peintre industriel
# 10       10                       Manutentionnaire
# 11       11                  Management industriel
# 12       12                             Magasinier
# 13       13          Infirmier de santé au travail
# 14       14                       Expert-comptable
# 15       15                      Electromécanicien
# 16       16        Animateur de ventes / Promotion
# 17       17                               Coffreur
# 18       18               Chauffeur SPL messagerie
# 19       19  Chauffeur PL national / international
# 20       20                            Charpentier
# 21       21                                Cariste
# 22       22                     Auditeur comptable
# 23       23                 Assistant de direction
# 24       24                             Artistique
# 25       25        Accompagnant éducatif et social
#
#                                           consequents  size
# 0   [Chauffeur VL, Hotliner, Manoeuvre, Manutentio...     9
# 1   [Cariste, Magasinier, Manutentionnaire, Prépar...     4
# 2      [Electrotechnicien, Technicien de maintenance]     2
# 3        [Manutentionnaire, Préparateur de commandes]     2
# 4                   [Chargé de clientèle, Commercial]     2
# 5        [Manutentionnaire, Préparateur de commandes]     2
# 6        [Assistant polyvalent / Secrétaire, Vendeur]     2
# 7                          [Préparateur de commandes]     1
# 8                          [Préparateur de commandes]     1
# 9                          [Préparateur de commandes]     1
# 10                         [Préparateur de commandes]     1
# 11                         [Chef d'équipe logistique]     1
# 12                         [Préparateur de commandes]     1
# 13                                        [Infirmier]     1
# 14                                [Comptable général]     1
# 15                        [Technicien de maintenance]     1
# 16                                          [Vendeur]     1
# 17                         [Préparateur de commandes]     1
# 18           [Chauffeur SPL national / international]     1
# 19                          [Chauffeur PL messagerie]     1
# 20                         [Préparateur de commandes]     1
# 21                         [Préparateur de commandes]     1
# 22                                [Comptable général]     1
# 23                [Assistant polyvalent / Secrétaire]     1
# 24                                          [Vendeur]     1
# 25                                    [Aide soignant]     1

# %%
clusters_df['size'].value_counts()
# Out:
# 1    19
# 2     5
# 9     1
# 4     1
# Name: size, dtype: int64

# %% [markdown]
# # Conclusion
#
# We can retain the rules whose rules have lift > 1 and  sufficiently "high" confidence at the same time as valid associations of professions.

# %% [markdown]
# ## Save the result

# %%
clusters_df.to_csv(os.path.join(RESULTS, 'association-rules-professions-per-cluster.csv'), index=False)
